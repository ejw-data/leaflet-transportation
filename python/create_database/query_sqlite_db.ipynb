# %%
import sqlite3
from sqlite3 import Error
database_file_location = "../../static/data/transportation.db"

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
def select_all_transportation(conn):
    """
    Query all rows in the transporation table
    :param conn: the Connection object
    :return:
    """

    cur = conn.cursor()
    cur.execute("SELECT city, june2020 FROM population")
    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
def main():
    database = database_file_location
    # create a database connection
    conn = create_connection(database)
    with conn:
        print(f"2. Query all transportation data")
        select_all_transportation(conn)

# %%
if __name__ == '__main__':
    main()
# Out:
# 2. Query all transportation data
# ('New York', 8804194.0)
# ('Los Angeles', 3898767.0)
# ('Chicago', 2746352.0)
# ('Houston', 2301572.0)
# ('Phoenix', 1608190.0)
# ('Philadelphia', 1603799.0)
# ('San Antonio', 1434367.0)
# ('San Diego', 1386960.0)
# ('Dallas', 1304317.0)
# ('Austin', 961900.0)
# ('Jacksonville', 949616.0)
# ('San Jose', 1013221.0)
# ('Fort Worth', 918937.0)
# ('Columbus', 905839.0)
# ('Charlotte', 874607.0)
# ('Indianapolis', 887661.0)
# ('San Francisco', 873959.0)
# ('Seattle', 737018.0)
# ('Denver', 715538.0)
# ('Oklahoma City', 681084.0)
# ('Nashville', 689454.0)
# ('El Paso', 678697.0)
# ('Washington', 689546.0)
# ('Las Vegas', 644866.0)
# ('Boston', 675632.0)
# ('Portland', 652518.0)
# ('Louisville', 632550.0)
# ('Memphis', 631539.0)
# ('Detroit', 639115.0)
# ('Baltimore', 585693.0)
# ('Milwaukee', 577225.0)
# ('Albuquerque', 564581.0)
# ('Tucson', 542656.0)
# ('Fresno', 542252.0)
# ('Sacramento', 524924.0)
# ('Mesa', 504300.0)
# ('Kansas City', 507971.0)
# ...
